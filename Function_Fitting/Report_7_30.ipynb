# %% [markdown]
# **mu=0.2**
# ![image.png](attachment:image.png)
# **同相位**
#
# count    90.000000
#
# mean     -0.035825
#
# std       0.297416
#
# min      -0.458370
#
# 25%      -0.335175
#
# 50%      -0.072793
#
# 75%       0.193407
#
# max       0.402995
#
# dtype: float64

# %% [markdown]
# **反相位**
#
# count    60.000000
#
# mean      0.288626
#
# std       0.120662
#
# min       0.046037
#
# 25%       0.213691
#
# 50%       0.337755
#
# 75%       0.380347
#
# max       0.423502
# ![image.png](attachment:image.png)

# %% [markdown]
# **mu=5**
# **同相位**
# count    90.000000
# mean     -0.527583
# std       9.197959
# min     -11.834878
# 25%      -9.713009
# 50%      -1.101657
# 75%       8.345676
# max      11.781666
# ![image.png](attachment:image.png)

# %% [markdown]
# **反相位**
# count    60.000000
# mean      0.288626
# std       0.120662
# min       0.046037
# 25%       0.213691
# 50%       0.337755
# 75%       0.380347
# max       0.423502
# ![image.png](attachment:image.png)
